# %% [markdown]
# # EMG2QWERTY — Results Analysis
#
# Use this notebook to:
# - Load experiment results (from wandb or CSV)
# - Plot CER comparisons across architectures
# - Plot ablation curves (channels, data amount, sampling rate)
# - Generate figures for the writeup

# %% [markdown]
# ## 1. Architecture Comparison
#
# TODO: Load CER values from your experiment tracker and make a bar chart.
# - x-axis: model name (TDS baseline, LSTM, GRU, CNN+LSTM, Transformer)
# - y-axis: test CER
# - Include val CER as well for completeness

# %% [markdown]
# ## 2. Channel Ablation
#
# TODO: Plot CER vs. number of active channels.
# - x-axis: num_channels (4, 8, 16, 32)
# - y-axis: test CER
# - Insight to discuss: does CER plateau at some number of channels?
#   Does removing left vs right hand matter more?

# %% [markdown]
# ## 3. Data Amount Ablation
#
# TODO: Plot learning curve — CER vs. fraction of training data.
# - x-axis: training fraction (0.25, 0.5, 0.75, 1.0) or approximate hours
# - y-axis: test CER
# - Insight: is the model data-hungry or does it plateau early?

# %% [markdown]
# ## 4. Sampling Rate Ablation
#
# TODO: Plot CER vs. sampling rate.
# - x-axis: sample rate (250, 500, 1000, 2000 Hz)
# - y-axis: test CER
# - Insight: what frequency content matters for EMG keystroke prediction?

# %% [markdown]
# ## 5. Training Curves
#
# TODO: Plot val CER over epochs for each model on the same axes.
# - Helps show convergence speed differences between architectures
# - Useful for discussion section
